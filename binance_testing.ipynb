# %%
from main.trade_live import client, trade_live
from main.rules import *

# get all symbol prices
prices = client.get_margin_all_pairs()
usdt_tickers = [p['symbol'] for p in prices if p['symbol'].endswith('USDT')]
usdt_tickers

# %%
trade_live(
    usdt_tickers, 
    [return_filter, volume_filter], # 1
    [breakout, volume_breakout], # 2
    [upper_donchian_breach], # 3
    [],
    2, 
    **{
        'return_filter_window_size': '1d',
        'min_return': 0,
        'min_volume': 200_000,

        'direction_interval': client.KLINE_INTERVAL_30MINUTE,
        'breakout_bars': 2*24, # 1d
        'volume_ma_bars':2*24,

        'entry_interval': client.KLINE_INTERVAL_5MINUTE,
        'donchian_entry_bars': 12,

        'atr_bars': 30,
        'max_leverage': 0.9,
        'min_loss_atr': 3
    }
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 trade_live(
#       2     usdt_tickers,
#       3     [return_filter, volume_filter], # 1
#       4     [breakout, volume_breakout], # 2
#       5     [upper_donchian_breach], # 3
#       6     [],
#       7     2,
#       8     **{
#       9         'return_filter_window_size': '1d',
#      10         'min_return': 0,
#      11         'min_volume': 200_000,
#      12
#      13         'direction_interval': client.KLINE_INTERVAL_30MINUTE,
#      14         'breakout_bars': 2*24, # 1d
#      15         'volume_ma_bars':2*24,
#      16
#      17         'entry_interval': client.KLINE_INTERVAL_5MINUTE,
#      18         'donchian_entry_bars': 12,
#      19
#      20         'atr_bars': 30,
#      21         'max_leverage': 0.9,
#      22         'min_loss_atr': 3
#      23     }
#      24 )
#
# ...
